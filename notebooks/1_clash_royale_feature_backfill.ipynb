# %%
import requests
import json
import os
import urllib.parse


def clean_battle_data(battle_data):
    # Define keys to retain
    desired_keys = {'name', 'level', 'elixirCost', 'rarity'}
    
    def filter_card_data(card):
        # Filter each card's data to retain only desired keys
        return {key: card[key] for key in card if key in desired_keys}

    def process_team_or_opponent(team_or_opponent):
        # Process each team or opponent's cards
        team_or_opponent['cards'] = [filter_card_data(card) for card in team_or_opponent['cards']]
        return team_or_opponent

    # Process the entire battle data
    for battle in battle_data:
        battle['team'] = [process_team_or_opponent(member) for member in battle['team']]
        battle['opponent'] = [process_team_or_opponent(member) for member in battle['opponent']]
    
    return battle_data

# Example usage with your JSON data
import json

# Assuming `battle_data` is your original JSON response loaded as a Python object
#cleaned_data = clean_battle_data(battle_data)

# Pretty-print the cleaned data
#print(json.dumps(cleaned_data, indent=2))

def get_player_data(player_tag, api_key):
    # URL-encode the player tag
    #encoded_tag = urllib.parse.quote(player_tag)
    
    # Define the API endpoint
    url = f'https://api.clashroyale.com/v1/players/{player_tag}/battlelog'
    
    # Set up the headers with the API key
    headers = {
        'Accept': 'application/json',
        'Authorization': f'Bearer {api_key}'
    }
    
    # Make the GET request to the API
    response = requests.get(url, headers=headers)
    
    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f'Error: {response.status_code}')
        return None

if __name__ == '__main__':
    # 1. Read the API key from the 'data/clash-royale-api-key.txt' file
    key_file_path = os.path.join('../data/clash-royale-api-key.txt')
    with open(key_file_path, 'r') as file:
        api_key = file.read().strip()
    
    # 2. Specify the player tag (URL-encoded # is often %23 in Clash Royale)
    player_tag = '%232LGY9G'  # Replace with the actual player tag, e.g. #2LGY9G -> %232LGY9G
    
    # 3. Call the API
    player_data = get_player_data(player_tag, api_key)
    if player_data:
        # 4. Clean the data
        cleaned_data = clean_battle_data(player_data)

        # 5. Save cleaned data to 'outputCR.json' in the 'data' folder
        output_path = os.path.join('../data/outputCR.json')
        with open(output_path, 'w', encoding='utf-16') as out_file:
            json.dump(cleaned_data, out_file, indent=2)
        
        # 6. Print the JSON file contents
        print(f"Saved cleaned data to: {output_path}\n")
        print("Printing contents of outputCR.json:\n")
        with open(output_path, 'r', encoding='utf-16') as in_file:
            file_data = json.load(in_file)
            print(json.dumps(file_data, indent=2))
    else:
        print("No data received from API. Please check your player tag or API key.")
# Out:
# Saved cleaned data to: ../data/outputCR.json
#
# Printing contents of outputCR.json:
#
# [
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241228T135508.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "crowns": 1,
#         "kingTowerHitPoints": 5721,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Royal Giant",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Barbarian Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Fisherman",
#             "level": 4,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Skeleton King",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 4
#           },
#           {
#             "name": "Mother Witch",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Tombstone",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Royal Chef",
#             "id": 159000004,
#             "level": 2,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/CLxP2o0iX7q9peMkekI8Ki4DgWixra8L5aUbiAeBU9U.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 3.25
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#2YC8JRR2G",
#         "name": "killergamer",
#         "trophyChange": 30,
#         "crowns": 2,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           692
#         ],
#         "cards": [
#           {
#             "name": "Mega Knight",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 7
#           },
#           {
#             "name": "Bats",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Bandit",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Arrows",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Archer Queen",
#             "level": 3,
#             "rarity": "champion",
#             "elixirCost": 5
#           },
#           {
#             "name": "Prince",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Wall Breakers",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 6.63
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241228T135118.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "crowns": 1,
#         "kingTowerHitPoints": 0,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Royal Giant",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Barbarian Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Fisherman",
#             "level": 4,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Skeleton King",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 4
#           },
#           {
#             "name": "Mother Witch",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Tombstone",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Royal Chef",
#             "id": 159000004,
#             "level": 2,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/CLxP2o0iX7q9peMkekI8Ki4DgWixra8L5aUbiAeBU9U.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 1.1
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#V0C8PCYUP",
#         "name": "J.MR\u2713",
#         "trophyChange": 30,
#         "crowns": 3,
#         "kingTowerHitPoints": 5755,
#         "princessTowersHitPoints": [
#           3668
#         ],
#         "clan": {
#           "tag": "#GRLVLPR0",
#           "name": "TERROR",
#           "badgeId": 16000009
#         },
#         "cards": [
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Mega Knight",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 7
#           },
#           {
#             "name": "Elixir Golem",
#             "level": 10,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Bomb Tower",
#             "level": 10,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Hog Rider",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Witch",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Goblin Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.05
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T145303.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "crowns": 0,
#         "kingTowerHitPoints": 5040,
#         "princessTowersHitPoints": [
#           2714
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.56
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#9JYUCRP2Q",
#         "name": "\uc6d0\uc8fc\ubbfc\uc900\uc6b0",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5370,
#         "princessTowersHitPoints": [
#           2294,
#           454
#         ],
#         "clan": {
#           "tag": "#9VCR0LJQ",
#           "name": "\uc81c\ubc1c\uc544\ubb34\ub098\uc640\uc918\uc694",
#           "badgeId": 16000126
#         },
#         "cards": [
#           {
#             "name": "Mortar",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Goblin Gang",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Barbarian Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Tornado",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Goblin Drill",
#             "level": 7,
#             "rarity": "epic",
#             "elixirCost": 4
#           },
#           {
#             "name": "Ice Wizard",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Monk",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 5
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.2
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T141311.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "trophyChange": 30,
#         "crowns": 2,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           2209
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 4.99
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#V8RQVGCVQ",
#         "name": "\uac13\ub300\ud604",
#         "crowns": 1,
#         "kingTowerHitPoints": 4911,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#QCL2YJY0",
#           "name": "\uae40\ub300\ud604\uacfc \uc544\uc774\ub4e4",
#           "badgeId": 16000170
#         },
#         "cards": [
#           {
#             "name": "Mega Knight",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 7
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Prince",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Princess",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Fisherman",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Baby Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 4
#           },
#           {
#             "name": "Guards",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 4.92
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T140937.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5472,
#         "princessTowersHitPoints": [
#           2958,
#           699
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.41
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#YG2JYVCY",
#         "name": "papillon d'or",
#         "crowns": 0,
#         "kingTowerHitPoints": 4244,
#         "princessTowersHitPoints": [
#           3327
#         ],
#         "clan": {
#           "tag": "#QG02CYL",
#           "name": "les conbattants",
#           "badgeId": 16000060
#         },
#         "cards": [
#           {
#             "name": "Electro Giant",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 7
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Minions",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Monk",
#             "level": 3,
#             "rarity": "champion",
#             "elixirCost": 5
#           },
#           {
#             "name": "Princess",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Witch",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Dart Goblin",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Dagger Duchess",
#             "id": 159000002,
#             "level": 5,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/MVj028nMLCmBuP3HlV503uxVAxFg7jyliJVZ5JYJ1h8.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.47
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T140617.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           3668,
#           2369
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 5.27
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#2R0LYY2V2",
#         "name": "felix",
#         "crowns": 0,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           3668
#         ],
#         "cards": [
#           {
#             "name": "P.E.K.K.A",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 7
#           },
#           {
#             "name": "Electro Wizard",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Dart Goblin",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "The Log",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Tower",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 5
#           },
#           {
#             "name": "Goblin Gang",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Bandit",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Ice Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 6.31
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T140224.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "crowns": 0,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           1833
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.75
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#L0YR0QCQU",
#         "name": "\u041f\u0435\u043b\u044c\u043c\u0435\u043d\u044c",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           3048,
#           173
#         ],
#         "clan": {
#           "tag": "#R82QV02",
#           "name": "Babushka",
#           "badgeId": 16000072
#         },
#         "cards": [
#           {
#             "name": "Ice Spirit",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Tesla",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 4
#           },
#           {
#             "name": "Knight",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Mighty Miner",
#             "level": 3,
#             "rarity": "champion",
#             "elixirCost": 4
#           },
#           {
#             "name": "The Log",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 2
#           },
#           {
#             "name": "Skeleton Army",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Hog Rider",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 3.69
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T135750.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           2757,
#           3668
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 1.85
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#UL88Y2",
#         "name": "toby",
#         "crowns": 0,
#         "kingTowerHitPoints": 5217,
#         "princessTowersHitPoints": [
#           1709
#         ],
#         "clan": {
#           "tag": "#RPYCRG0G",
#           "name": "better lootgang",
#           "badgeId": 16000147
#         },
#         "cards": [
#           {
#             "name": "P.E.K.K.A",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 7
#           },
#           {
#             "name": "Goblin Giant",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 6
#           },
#           {
#             "name": "Arrows",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fisherman",
#             "level": 4,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Ice Spirit",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Bomber",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Skeletons",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Royal Chef",
#             "id": 159000004,
#             "level": 5,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/CLxP2o0iX7q9peMkekI8Ki4DgWixra8L5aUbiAeBU9U.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.27
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241224T135439.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "crowns": 0,
#         "kingTowerHitPoints": 1820,
#         "princessTowersHitPoints": [
#           1678
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Elixir Golem",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Battle Healer",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Electro Dragon",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.92
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#9GG2PVUL",
#         "name": "Bach",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           1199,
#           2564
#         ],
#         "clan": {
#           "tag": "#CVJPLC",
#           "name": "Brothers n Arms",
#           "badgeId": 16000171
#         },
#         "cards": [
#           {
#             "name": "P.E.K.K.A",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 7
#           },
#           {
#             "name": "Wizard",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 5
#           },
#           {
#             "name": "Royal Ghost",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Electro Spirit",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Void",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Ram Rider",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 5
#           },
#           {
#             "name": "Bandit",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Zap",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Dagger Duchess",
#             "id": 159000002,
#             "level": 5,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/MVj028nMLCmBuP3HlV503uxVAxFg7jyliJVZ5JYJ1h8.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 1.89
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "challenge",
#     "battleTime": "20241221T140252.000Z",
#     "challengeId": 73009892,
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000036,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000474,
#       "name": "Challenge_AllCards_EventDeck_NoSet"
#     },
#     "challengeWinCountBefore": 4,
#     "deckSelection": "eventDeck",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "startingTrophies": 8000,
#         "crowns": 1,
#         "kingTowerHitPoints": 4824,
#         "princessTowersHitPoints": [
#           1516,
#           2146
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Electro Dragon",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Zap",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Elixir Golem",
#             "level": 9,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Battle Healer",
#             "level": 9,
#             "rarity": "rare",
#             "elixirCost": 4
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 11,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.49
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#PY9UV9U8U",
#         "name": "sirop de fraise",
#         "startingTrophies": 6629,
#         "crowns": 0,
#         "kingTowerHitPoints": 4824,
#         "princessTowersHitPoints": [
#           3052
#         ],
#         "clan": {
#           "tag": "#LQPVCRPR",
#           "name": "les zboubies",
#           "badgeId": 16000139
#         },
#         "cards": [
#           {
#             "name": "Goblin Barrel",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Ice Spirit",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Guards",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Cannon Cart",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "The Log",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 2
#           },
#           {
#             "name": "Princess",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Dart Goblin",
#             "level": 9,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Goblinstein",
#             "level": 1,
#             "rarity": "champion",
#             "elixirCost": 5
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 11,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.68
#       }
#     ],
#     "challengeTitle": "Vinci un emblema esclusivo!",
#     "isHostedMatch": false,
#     "leagueNumber": 1
#   },
#   {
#     "type": "challenge",
#     "battleTime": "20241221T135011.000Z",
#     "challengeId": 73009892,
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000036,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000474,
#       "name": "Challenge_AllCards_EventDeck_NoSet"
#     },
#     "challengeWinCountBefore": 4,
#     "deckSelection": "eventDeck",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "startingTrophies": 8000,
#         "crowns": 1,
#         "kingTowerHitPoints": 4317,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Electro Dragon",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Zap",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Giant Snowball",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Rage",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Inferno Dragon",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Elixir Golem",
#             "level": 9,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Elite Barbarians",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Battle Healer",
#             "level": 9,
#             "rarity": "rare",
#             "elixirCost": 4
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 11,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 1.75
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#809PCQ8C2",
#         "name": "Edu638\u2122",
#         "startingTrophies": 4318,
#         "crowns": 2,
#         "kingTowerHitPoints": 4824,
#         "princessTowersHitPoints": [
#           2247
#         ],
#         "cards": [
#           {
#             "name": "Goblinstein",
#             "level": 1,
#             "rarity": "champion",
#             "elixirCost": 5
#           },
#           {
#             "name": "Goblin Barrel",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Dart Goblin",
#             "level": 9,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Cannon Cart",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Princess",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Guards",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "The Log",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 2
#           },
#           {
#             "name": "Ice Spirit",
#             "level": 11,
#             "rarity": "common",
#             "elixirCost": 1
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 11,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.85
#       }
#     ],
#     "challengeTitle": "Vinci un emblema esclusivo!",
#     "isHostedMatch": false,
#     "leagueNumber": 1
#   },
#   {
#     "type": "challenge",
#     "battleTime": "20241221T134636.000Z",
#     "challengeId": 73009892,
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000036,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000474,
#       "name": "Challenge_AllCards_EventDeck_NoSet"
#     },
#     "challengeWinCountBefore": 3,
#     "deckSelection": "eventDeck",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "startingTrophies": 8000,
#         "crowns": 3,
#         "kingTowerHitPoints": 4824,
#         "princessTowersHitPoints": [
#           3052
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Electro Dragon",
#             "level": 6,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Zap",
#             "level": 11,
# ...
#           {
#             "name": "Tesla",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 4
#           },
#           {
#             "name": "Fire Spirit",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Hog Rider",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Earthquake",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Valkyrie",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "The Log",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Royal Chef",
#             "id": 159000004,
#             "level": 2,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/CLxP2o0iX7q9peMkekI8Ki4DgWixra8L5aUbiAeBU9U.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.85
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#JYLPQGGPJ",
#         "name": "Ernesto",
#         "crowns": 1,
#         "kingTowerHitPoints": 5580,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#9RQ8PJR",
#           "name": "Rican Royale",
#           "badgeId": 16000036
#         },
#         "cards": [
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Barbarians",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 5
#           },
#           {
#             "name": "Goblin Gang",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Dart Goblin",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Valkyrie",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Mirror",
#             "level": 8,
#             "rarity": "epic"
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Goblin Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 0.0
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241216T124914.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "crowns": 0,
#         "kingTowerHitPoints": 5418,
#         "princessTowersHitPoints": [
#           2160
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Skeletons",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Tesla",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 4
#           },
#           {
#             "name": "Fire Spirit",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 1
#           },
#           {
#             "name": "Hog Rider",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Earthquake",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           },
#           {
#             "name": "Valkyrie",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "The Log",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 1.42
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#90GUGVPUU",
#         "name": "\ud569\ub9ac\uc8fc\uc758",
#         "trophyChange": 30,
#         "crowns": 1,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           3178,
#           618
#         ],
#         "clan": {
#           "tag": "#2QUL9Y0",
#           "name": "\ud569\ub9ac\uc8fc\uc758",
#           "badgeId": 16000029
#         },
#         "cards": [
#           {
#             "name": "Mega Knight",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 7
#           },
#           {
#             "name": "Valkyrie",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Goblinstein",
#             "level": 3,
#             "rarity": "champion",
#             "elixirCost": 5
#           },
#           {
#             "name": "Arrows",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Rocket",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 6
#           },
#           {
#             "name": "Freeze",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 4
#           },
#           {
#             "name": "Wizard",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 5
#           },
#           {
#             "name": "Tesla",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 4
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Royal Chef",
#             "id": 159000004,
#             "level": 5,
#             "maxLevel": 6,
#             "rarity": "legendary",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/CLxP2o0iX7q9peMkekI8Ki4DgWixra8L5aUbiAeBU9U.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 2.17
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241216T124531.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "trophyChange": 30,
#         "crowns": 2,
#         "kingTowerHitPoints": 5832,
#         "princessTowersHitPoints": [
#           3389
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Royal Giant",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Barbarian Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Fisherman",
#             "level": 4,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Skeleton King",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 4
#           },
#           {
#             "name": "Mother Witch",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Tombstone",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 1.6
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#CRL82RCG9",
#         "name": "Thanos28739",
#         "crowns": 1,
#         "kingTowerHitPoints": 3381,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#GLC9C28C",
#           "name": "SmanixClash",
#           "badgeId": 16000171
#         },
#         "cards": [
#           {
#             "name": "Mega Knight",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 7
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Witch",
#             "level": 7,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Goblin Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 3
#           },
#           {
#             "name": "Royal Recruits",
#             "level": 12,
#             "rarity": "common",
#             "elixirCost": 7
#           },
#           {
#             "name": "The Log",
#             "level": 3,
#             "rarity": "legendary",
#             "elixirCost": 2
#           },
#           {
#             "name": "Goblinstein",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 5
#           },
#           {
#             "name": "P.E.K.K.A",
#             "level": 7,
#             "rarity": "epic",
#             "elixirCost": 7
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 12,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 3.88
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   },
#   {
#     "type": "pathOfLegend",
#     "battleTime": "20241216T124213.000Z",
#     "isLadderTournament": false,
#     "arena": {
#       "id": 54000098,
#       "name": "Legendary Arena"
#     },
#     "gameMode": {
#       "id": 72000464,
#       "name": "Ranked1v1_NewArena2"
#     },
#     "deckSelection": "collection",
#     "team": [
#       {
#         "tag": "#2LGY9G",
#         "name": "Diwel26",
#         "trophyChange": 30,
#         "crowns": 2,
#         "kingTowerHitPoints": 3918,
#         "princessTowersHitPoints": [
#           2186
#         ],
#         "clan": {
#           "tag": "#YULCL0YQ",
#           "name": "ITA",
#           "badgeId": 16000081
#         },
#         "cards": [
#           {
#             "name": "Royal Giant",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 6
#           },
#           {
#             "name": "Firecracker",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "Barbarian Barrel",
#             "level": 8,
#             "rarity": "epic",
#             "elixirCost": 2
#           },
#           {
#             "name": "Fisherman",
#             "level": 4,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Skeleton King",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 4
#           },
#           {
#             "name": "Mother Witch",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 4
#           },
#           {
#             "name": "Tombstone",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 3
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 4.2
#       }
#     ],
#     "opponent": [
#       {
#         "tag": "#Q89YVL8G",
#         "name": "Zitrone mit Hut",
#         "crowns": 1,
#         "kingTowerHitPoints": 5524,
#         "princessTowersHitPoints": null,
#         "clan": {
#           "tag": "#L9JQ99VG",
#           "name": "BRAZZERS",
#           "badgeId": 16000140
#         },
#         "cards": [
#           {
#             "name": "Mortar",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 4
#           },
#           {
#             "name": "Bats",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 2
#           },
#           {
#             "name": "Goblinstein",
#             "level": 2,
#             "rarity": "champion",
#             "elixirCost": 5
#           },
#           {
#             "name": "Miner",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 3
#           },
#           {
#             "name": "Cannon Cart",
#             "level": 7,
#             "rarity": "epic",
#             "elixirCost": 5
#           },
#           {
#             "name": "Fireball",
#             "level": 11,
#             "rarity": "rare",
#             "elixirCost": 4
#           },
#           {
#             "name": "Goblin Gang",
#             "level": 13,
#             "rarity": "common",
#             "elixirCost": 3
#           },
#           {
#             "name": "The Log",
#             "level": 5,
#             "rarity": "legendary",
#             "elixirCost": 2
#           }
#         ],
#         "supportCards": [
#           {
#             "name": "Tower Princess",
#             "id": 159000000,
#             "level": 13,
#             "maxLevel": 14,
#             "rarity": "common",
#             "iconUrls": {
#               "medium": "https://api-assets.clashroyale.com/cards/300/Nzo5Gjbh7NG6O3Hyu7ev54Pu5zK7vDMR2fbpGdVsS64.png"
#             }
#           }
#         ],
#         "globalRank": null,
#         "elixirLeaked": 4.94
#       }
#     ],
#     "isHostedMatch": false,
#     "leagueNumber": 4
#   }
# ]

# %%
import pandas as pd
import json

# Dictionary mapping card names to IDs
cards_dict = {
    "Archers": 1,
    "Archer Queen": 2,
    "Arrows": 3,
    "Baby Dragon": 4,
    "Balloon": 5,
    "Bandit": 6,
    "Barbarians": 7,
    "Barbarian Barrel": 8,
    "Barbarian Hut": 9,
    "Bats": 10,
    "Battle Healer": 11,
    "Battle Ram": 12,
    "Bomber": 13,
    "Bomb Tower": 14,
    "Bowler": 15,
    "Bush Goblins": 16,
    "Cannon": 17,
    "Cannon Cart": 18,
    "Cursed Hog": 19,
    "Dark Prince": 20,
    "Dart Goblin": 21,
    "Defensive Buildings": 22,
    "Earthquake": 23,
    "Electro Dragon": 24,
    "Electro Giant": 25,
    "Electro Spirit": 26,
    "Electro Wizard": 27,
    "Elixir Blob": 28,
    "Elixir Collector": 29,
    "Elixir Golem": 30,
    "Elixir Golemite": 31,
    "Executioner": 32,
    "Fireball": 33,
    "Fire Spirit": 34,
    "Firecracker": 35,
    "Fisherman": 36,
    "Flying Machine": 37,
    "Freeze": 38,
    "Furnace": 39,
    "Giant": 40,
    "Giant Skeleton": 41,
    "Giant Snowball": 42,
    "Goblin Barrel": 43,
    "Goblin Brawler": 44,
    "Goblin Cage": 45,
    "Goblin Curse": 46,
    "Goblin Demolisher": 47,
    "Goblin Drill": 48,
    "Goblin Gang": 49,
    "Goblin Giant": 50,
    "Goblin Hut": 51,
    "Goblin Machine": 52,
    "Goblinstein": 53,
    "Goblins": 54,
    "Golden Knight": 55,
    "Golem": 56,
    "Golemite": 57,
    "Graveyard": 58,
    "Guardienne": 59,
    "Guards": 60,
    "Heal Spirit": 61,
    "Hog Rider": 62,
    "Hunter": 63,
    "Ice Golem": 64,
    "Ice Spirit": 65,
    "Ice Wizard": 66,
    "Inferno Dragon": 67,
    "Inferno Tower": 68,
    "Knight": 69,
    "Lava Hound": 70,
    "Lava Pup": 71,
    "Lightning": 72,
    "Little Prince": 73,
    "Log": 74,
    "Lumberjack": 75,
    "Magic Archer": 76,
    "Mega Knight": 77,
    "Mega Minion": 78,
    "Mighty Miner": 79,
    "Miner": 80,
    "Mini P.E.K.K.A.": 81,
    "Minion Horde": 82,
    "Minions": 83,
    "Monk": 84,
    "Monster": 85,
    "Mortar": 86,
    "Mother Witch": 87,
    "Musketeer": 88,
    "Night Witch": 89,
    "P.E.K.K.A.": 90,
    "Phoenix": 91,
    "Phoenix Egg": 92,
    "Poison": 93,
    "Prince": 94,
    "Princess": 95,
    "Ram Rider": 96,
    "Rage": 97,
    "Rascal Boy": 98,
    "Rascal Girl": 99,
    "Reborn Phoenix": 100,
    "Rocket": 101,
    "Royal Delivery": 102,
    "Royal Ghost": 103,
    "Royal Giant": 104,
    "Royal Hogs": 105,
    "Royal Recruits": 106,
    "Skeleton Army": 107,
    "Skeleton Barrel": 108,
    "Skeleton Dragons": 109,
    "Skeleton King": 110,
    "Skeletons": 111,
    "Sparky": 112,
    "Spear Goblins": 113,
    "Spawners": 114,
    "Suspicious Bush": 115,
    "Tesla": 116,
    "The Log": 117,
    "Three Musketeers": 118,
    "Tombstone": 119,
    "Tornado": 120,
    "Valkyrie": 121,
    "Void": 122,
    "Wall Breakers": 123,
    "Witch": 124,
    "Wizard": 125,
    "X-Bow": 126,
    "Zap": 127,
    "Zappies": 128
}

# Assuming the provided JSON is saved in 'outputCR.json'
try:
    with open('../data/outputCR.json', 'r', encoding='utf-16') as f:
        battle_data = json.load(f)  # Load the JSON data
except FileNotFoundError:
    print("File not found. Ensure 'outputCR.json' exists in the directory.")
    battle_data = None
except json.JSONDecodeError as e:
    print(f"Invalid JSON format: {e}")
    battle_data = None

if battle_data:
    # Function to process a single player's data
    def process_player_data(player, is_team=True):
        deck = [cards_dict.get(card['name'], -1) for card in player['cards']]  # Convert names to IDs
        support_cards = [cards_dict.get(card['name'], -1) for card in player.get('supportCards', [])]
        trophy_change = player.get('trophyChange', 0) * (1 if is_team else -1)
        return {
            'Player Name': player['name'],
            **{f'Card {i+1}': card for i, card in enumerate(deck)},  # One column per card
            #'Support Cards': ', '.join(map(str, support_cards)),
            #'Trophy Change': trophy_change,
            #'Crowns': player['crowns']
        }

    # Collect all matches
    all_matches = []

    for match in battle_data:
        team = match['team'][0]
        opponent = match['opponent'][0]
        team_data = process_player_data(team, is_team=True)
        opponent_data = process_player_data(opponent, is_team=False)

        # Add Win or Lose based on crowns
        if team['crowns'] > opponent['crowns']:
            team_data['Result'] = 'WIN'
            opponent_data['Result'] = 'LOSE'
        elif team['crowns'] < opponent['crowns']:
            team_data['Result'] = 'LOSE'
            opponent_data['Result'] = 'WIN'
        else:
            team_data['Result'] = 'DRAW'
            opponent_data['Result'] = 'DRAW'

        all_matches.append(team_data)
        all_matches.append(opponent_data)

    # Create the DataFrame
    df = pd.DataFrame(all_matches)

    # Display the DataFrame
    print(df)
else:
    print("No battle data available.")
# Out:
#         Player Name  Card 1  Card 2  Card 3  Card 4  Card 5  Card 6  Card 7  \
# 0           Diwel26     104      35       8      36      33     110      87
# 1       killergamer      77      10       6       3       2      94     123
# 2           Diwel26     104      35       8      36      33     110      87
# 3             J.MR✓      35      77      30      33      14      62     124
# 4           Diwel26      30      11     127      97      67      24      -1
# 5             원주민준우      86      24      49       8     120      48      66
# 6           Diwel26      30      11     127      97      67      24      -1
# 7               갓대현      77      35      94      95      33      36       4
# 8           Diwel26      30      11     127      97      67      24      -1
# 9     papillon d'or      25      35      83      33      84      95     124
# 10          Diwel26      30      11     127      97      67      24      -1
# 11            felix      -1      27      21     117      68      49       6
# 12          Diwel26      30      11     127      97      67      24      -1
# 13         Пельмень      65      35     116      69      79     117     107
# 14          Diwel26      30      11     127      97      67      24      -1
# 15             toby      -1      50       3      36      97      65      13
# 16          Diwel26      30      11     127      97      67      24      -1
# 17             Bach      -1     125     103      26     122      96       6
# 18          Diwel26      24     127      42      97      67      30      -1
# 19  sirop de fraise      43      65      60      18     117      95      21
# 20          Diwel26      24     127      42      97      67      30      -1
# 21          Edu638™      53      43      21      18      95      60     117
# 22          Diwel26      24     127      42      97      67      30      -1
# 23           vaccoc      -1      77     125      10      27     127      49
# 24          Diwel26      24     127      42      97      67      30      -1
# 25              Gui      86      10      80      49     110      18      87
# 26          Diwel26      24     127      42      97      67      30      -1
# 27           Arthur      86      10      53      18      80      33      49
# 28          Diwel26      24     127      42      97      67      30      -1
# 29             Simo      35      77     105      67      13     124      10
# 30          Diwel26     104      35       8      36      33     110      87
# 31         pancakes      13      42      48      65     111     117      53
# 32          Diwel26     104      35       8      36      33     110      87
# 33           LoKrox      86     116      69     117     111      53      10
# 34          Diwel26     104      35       8      36      33     110      87
# 35         dir egal      35      77      -1     121      10     124      62
# 36          Diwel26     104      35       8      36      33     110      87
# 37             stef      35     116      69      62     102       3     113
# 38          Diwel26     104      35       8      36      33     110      87
# 39       mariomoron     106      35      26       3     117      64      94
# 40          Diwel26     104      35       8      36      33     110      87
# 41            ⓐⓗⓜⓔⓓ      35      77     121     124      -1     101       3
# 42          Diwel26      35     111     116      34      62      23     121
# 43       David43215      35      -1      21      27      96      49      84
# 44          Diwel26      35     111     116      34      62      23     121
# 45         Koentjeh      35      10       3      68      25      60      21
# 46          Diwel26      35     111     116      34      62      23     121
# 47             Zozi      10      77      43     121     116      33      95
# 48          Diwel26      35     111     116      34      62      23     121
# 49          bafongo     121      35     117      60      65      97       3
# 50          Diwel26      35     111     116      34      62      23     121
# 51         scarface      77      50      53       3      13     107      36
# 52          Diwel26      35     111     116      34      62      23     121
# 53          Ernesto      35       7      49      21     121      -1      33
# 54          Diwel26      35     111     116      34      62      23     121
# 55             합리주의      77     121      53       3     101      38     125
# 56          Diwel26     104      35       8      36      33     110      87
# 57      Thanos28739      77      35     124      43     106     117      53
# 58          Diwel26     104      35       8      36      33     110      87
# 59  Zitrone mit Hut      86      10      53      80      18      33      49
#
#     Card 8 Result
# 0      119   LOSE
# 1      127    WIN
# 2      119   LOSE
# 3       43    WIN
# 4       42   LOSE
# 5       84    WIN
# 6       42    WIN
# 7       60   LOSE
# 8       42    WIN
# 9       21   LOSE
# 10      42    WIN
# 11      64   LOSE
# 12      42   LOSE
# 13      62    WIN
# 14      42    WIN
# 15     111   LOSE
# 16      42   LOSE
# 17     127    WIN
# 18      11    WIN
# 19      53   LOSE
# 20      11   LOSE
# 21      65    WIN
# 22      11    WIN
# 23       3   LOSE
# 24      11    WIN
# 25       3   LOSE
# 26      11    WIN
# 27     117   LOSE
# 28      11    WIN
# 29     117   LOSE
# 30     119    WIN
# 31      88   LOSE
# 32     119   LOSE
# 33       3    WIN
# 34     119   LOSE
# 35     127    WIN
# 36     119   LOSE
# 37      23    WIN
# 38     119    WIN
# 39      62   LOSE
# 40     119   LOSE
# 41      62    WIN
# 42     117   LOSE
# 43     117    WIN
# 44     117   LOSE
# 45      -1    WIN
# 46     117   LOSE
# 47       3    WIN
# 48     117    WIN
# 49      21   LOSE
# 50     117    WIN
# 51      97   LOSE
# 52     117    WIN
# 53      43   LOSE
# 54     117   LOSE
# 55     116    WIN
# 56     119    WIN
# 57      -1   LOSE
# 58     119    WIN
# 59     117   LOSE

# %%
import os
import hopsworks
import pandas as pd

# 1. Read your Hopsworks API Key from a file or environment variable
#    For example, if stored in 'hopsworks-api-key.txt'
with open('../data/hopsworks-api-key.txt', 'r') as f:
    api_key = f.read().strip()

# 2. Set the environment variable for Hopsworks
os.environ["HOPSWORKS_API_KEY"] = api_key

# 3. Log in to your Hopsworks project
project = hopsworks.login()  # or hopsworks.login(api_key_value=api_key)
fs = project.get_feature_store()

# 4. Suppose we already have a DataFrame named df (e.g., from the previous step)
#    that has columns like: "player_name", "deck", "crowns", "result", "battle_time", etc.
#    Make sure df is defined before this script or above in the same script:
# df = ...

# 5. Create (or get) a feature group
cr_feature_group = fs.get_or_create_feature_group(
    name="clash_royale_features",
    version=1,
    description="Clash Royale cleaned match features",
    primary_key=["player_name"],  # columns that uniquely identify each row
)

# 6. Insert data into the feature group
cr_feature_group.insert(df)

print("DataFrame inserted into Hopsworks Feature Store successfully!")
# Out:
# 2025-01-03 18:03:58,087 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2025-01-03 18:03:58,095 INFO: Initializing external client
# 2025-01-03 18:03:58,096 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-01-03 18:03:59,399 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1175700
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1175700/fs/1166403/fg/1393497
# ---------------------------------------------------------------------------
# KafkaException                            Traceback (most recent call last)
# Cell In[5], line 31
#      23 cr_feature_group = fs.get_or_create_feature_group(
#      24     name="clash_royale_features",
#      25     version=1,
#      26     description="Clash Royale cleaned match features",
#      27     primary_key=["player_name"],  # columns that uniquely identify each row
#      28 )
#      30 # 6. Insert data into the feature group
# ---> 31 cr_feature_group.insert(df)
#      33 print("DataFrame inserted into Hopsworks Feature Store successfully!")
#
# File c:\Users\steve\Anaconda3\envs\ClashRoyale\lib\site-packages\hsfs\feature_group.py:2940, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, wait)
#    2937 if not self._id and self._offline_backfill_every_hr is not None:
#    2938     write_options["offline_backfill_every_hr"] = self._offline_backfill_every_hr
# -> 2940 job, ge_report = self._feature_group_engine.insert(
#    2941     self,
#    2942     feature_dataframe=feature_dataframe,
#    2943     overwrite=overwrite,
#    2944     operation=operation,
#    2945     storage=storage.lower() if storage is not None else None,
#    2946     write_options=write_options,
#    2947     validation_options={"save_report": True, **validation_options},
#    2948 )
#    2950 if engine.get_type().startswith("spark") and not self.stream:
#    2951     # Also, only compute statistics if stream is False.
#    2952     # if True, the backfill job has not been triggered and the data has not been inserted (it's in Kafka)
#    2953     self.compute_statistics()
#
# File c:\Users\steve\Anaconda3\envs\ClashRoyale\lib\site-packages\hsfs\core\feature_group_engine.py:212, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options)
#     208 if overwrite:
#     209     self._feature_group_api.delete_content(feature_group)
#     211 return (
# --> 212     engine.get_instance().save_dataframe(
#     213         feature_group,
#     214         feature_dataframe,
#     215         "bulk_insert" if overwrite else operation,
#     216         feature_group.online_enabled,
#     217         storage,
#     218         offline_write_options,
#     219         online_write_options,
#     220     ),
#     221     ge_report,
#     222 )
#
# File c:\Users\steve\Anaconda3\envs\ClashRoyale\lib\site-packages\hsfs\engine\python.py:815, in Engine.save_dataframe(self, feature_group, dataframe, operation, online_enabled, storage, offline_write_options, online_write_options, validation_id)
#     800 def save_dataframe(
#     801     self,
#     802     feature_group: FeatureGroup,
#    (...)
#     809     validation_id: Optional[int] = None,
#     810 ) -> Optional[job.Job]:
#     811     if (
#     812         hasattr(feature_group, "EXTERNAL_FEATURE_GROUP")
#     813         and feature_group.online_enabled
#     814     ) or feature_group.stream:
# --> 815         return self._write_dataframe_kafka(
#     816             feature_group, dataframe, offline_write_options
#     817         )
#     818     else:
#     819         # for backwards compatibility
#     820         return self.legacy_save_dataframe(
#     821             feature_group,
#     822             dataframe,
#    (...)
#     828             validation_id,
#     829         )
#
# File c:\Users\steve\Anaconda3\envs\ClashRoyale\lib\site-packages\hsfs\engine\python.py:1455, in Engine._write_dataframe_kafka(self, feature_group, dataframe, offline_write_options)
#    1448 producer, headers, feature_writers, writer = kafka_engine.init_kafka_resources(
#    1449     feature_group,
#    1450     offline_write_options,
#    1451     project_id=client.get_instance()._project_id,
#    1452 )
#    1453 if not feature_group._multi_part_insert:
#    1454     # set initial_check_point to the current offset
# -> 1455     initial_check_point = kafka_engine.kafka_get_offsets(
#    1456         topic_name=feature_group._online_topic_name,
#    1457         feature_store_id=feature_group.feature_store_id,
#    1458         offline_write_options=offline_write_options,
#    1459         high=True,
#    1460     )
#    1462 acked, progress_bar = kafka_engine.build_ack_callback_and_optional_progress_bar(
#    1463     n_rows=dataframe.shape[0],
#    1464     is_multi_part_insert=feature_group._multi_part_insert,
#    1465     offline_write_options=offline_write_options,
#    1466 )
#    1468 if isinstance(dataframe, pd.DataFrame):
#
# File c:\Users\steve\Anaconda3\envs\ClashRoyale\lib\site-packages\hsfs\core\kafka_engine.py:130, in kafka_get_offsets(topic_name, feature_store_id, offline_write_options, high)
#     123 def kafka_get_offsets(
#     124     topic_name: str,
#     125     feature_store_id: int,
#     126     offline_write_options: Dict[str, Any],
#     127     high: bool,
#     128 ) -> str:
#     129     consumer = init_kafka_consumer(feature_store_id, offline_write_options)
# --> 130     topics = consumer.list_topics(
#     131         timeout=offline_write_options.get("kafka_timeout", 6)
#     132     ).topics
#     133     if topic_name in topics.keys():
#     134         # topic exists
#     135         offsets = ""
#
# KafkaException: KafkaError{code=_TRANSPORT,val=-195,str="Failed to get metadata: Local: Broker transport failure"}
